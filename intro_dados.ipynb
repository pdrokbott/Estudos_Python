# %% [markdown]
# # Tipos de dados

# %%
empresa = "Acme"
vendas = 1250
faturamento = 23000.50
meta = True

print(type(empresa))
print(type(vendas))
print(type(faturamento))
print(type(meta))

# %% [markdown]
# # Operadores

# %%
vendas = 1250
preco_medio = 18.4
faturamento = vendas * preco_medio

print("Faturamento total:", faturamento)

# %% [markdown]
# # Conversões de tipos (casting)

# %%
valor_texto = "1250"
valor_num = int(valor_texto)  # converte texto -> número
print(valor_num * 2)

# %%
float("3.14")   # texto -> número decimal
str(42)         # número -> texto
bool(1)         # 1 vira True, 0 vira False

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### 🧩 Exercício 1 — Apresentação
# Crie três variáveis:
# - `nome`
# - `idade`
# - `cidade`
#
# Exiba uma frase usando f-string:
# > Meu nome é Pedro, tenho 24 anos e moro em Belo Horizonte.

# %%
nome="Pedro"
idade=24
cidade="Belo Horizonte"

print(f"Meu nome é {nome}, tenho {idade} anos e moro em {cidade}.")

# %% [markdown]
# ## 🧩 Exercício 2 — Tipos de dados
# Crie variáveis:
# - `produto` com o nome de um item
# - `quantidade` com um número inteiro
# - `preco` com um valor decimal
#
# Use `type()` para mostrar o tipo de cada uma delas.

# %%
produto = "carro"
quantidade = 30
preco = 134.34

print(type(produto))
print(type(quantidade))
print(type(preco))

# %% [markdown]
# ## 🧩 Exercício 3 — Cálculo simples
# Com as variáveis `quantidade` e `preco`, calcule o **valor total em estoque**.
# Exiba o resultado formatado com duas casas decimais:
# > Valor total em estoque: R$ 17503.75

# %%
quantidade = 10
preco = 45.5
valor_total = quantidade * preco

print(f"Valor total em estoque: {valor_total}")

# %% [markdown]
# ## 🧩 Exercício 4 — Conversão de tipos
# Você recebeu o preço de um produto como texto:
# > "59.90"
#
# Converta o valor para número (`float`), multiplique por 10 e mostre o resultado.

# %%
produto = "59.90"
valor = float(produto)
total = (valor * 10)
print(total)

# %% [markdown]
# ## 🧩 Exercício 5 — Booleanos
# Crie variáveis booleanas:
# - `em_estoque = True`
# - `em_promocao = False`
#
# Imprima frases que mostrem essas informações.
# Depois, teste as expressões:
# - `em_estoque and em_promocao`
# - `em_estoque or em_promocao`

# %%
em_estoque = True
em_promocao = False

print(f"O produto esta em estoque? {em_estoque}")
print(f"O produto esta em promoção? {em_promocao}")
print(f"Produto disponível e em promoção? {em_estoque and em_promocao}")
print(f"Produto disponível ou em promoção? {em_estoque or em_promocao}")

# %% [markdown]
# ## 🧩 Exercício 6 — Mini relatório
# Crie variáveis para:
# - `produto`
# - `preco_unitario`
# - `quantidade`
#
# Calcule o faturamento total (`preco_unitario * quantidade`)
# e exiba um relatório com todas as informações.

# %%
produto = "camiseta"
preco_unitario = 15.56
quantidade = 10

faturamento_total = preco_unitario * quantidade
print(f"Foram venidos {quantidade} unidades de {produto} no valor de {preco_unitario} totalizando uma venda total de R$ {faturamento_total}")

# %% [markdown]
# ## 🧩 Exercício 7 — Desafio interativo
# Peça ao usuário (com `input()`) o nome e o preço de um produto.
# Aumente o preço em **10%** e exiba o resultado formatado:
# > Preço com acréscimo de 10%: R$ 00.00

# %%
print("coloque o nome de um produto")
nome = input()
print("coloque o preco de um produto")
preco = int(input())

preco_acrescido = preco * 1.1

print(f"O seu produto {nome} teve um reajuste para {preco_acrescido}")

# %% [markdown]
# ## 🧩 Exercício final — Validação de entrada (fechamento do Módulo 2)
#
# Você vai criar um programa que:
#
# 1️⃣ Pede o **nome de um produto**
# 2️⃣ Pede o **preço**
# 3️⃣ Verifica se o preço digitado é um **número válido**
# 4️⃣ Se for válido, calcula o preço com **acréscimo de 10 %**
# 5️⃣ Se for inválido, mostra uma mensagem de erro amigável
#
# ---
#
# ### 💡 Dica de abordagem
#
# - Use `input()` para coletar os dados.
# - Para testar se o preço é numérico, use o método `.replace('.', '', 1).isdigit()`,
#   que permite um único ponto decimal.
# - Use `float()` apenas depois que tiver certeza de que o valor é válido.
# - Use uma estrutura `if / else` para decidir o que mostrar.
#
# ---
#
# ### 🎯 Exemplo de execução

# %%
from ntpath import relpath


print("Olá insira o nome do produto")
nome = input()
print("agora insira o preçdo do produto")
preco = input()
so_digitos = preco.replace(".","",1)
if so_digitos.isdigit():
    preco = float(preco)
    preco = preco * 1.1
    print(f"Seu novo preco do item {nome} é {preco}")
else:
    print("Número inválido") 
      # True
